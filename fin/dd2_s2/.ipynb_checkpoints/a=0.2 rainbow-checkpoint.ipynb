# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Loading the files
seq_t = np.loadtxt('seq.d')
seq_k = np.loadtxt('kep.d')
seq_s = np.loadtxt('static.d')
seq_d = np.loadtxt('erm.d')
quasi = np.loadtxt('quasi.d')
seq_1 = np.loadtxt('1.43.d')
seq_2 = np.loadtxt('2.01.d')
seq_3 = np.loadtxt('2.3.d')
seq_4 = np.loadtxt('2.64.d')
seq_5 = np.loadtxt('2.89.d')
seq_6 = np.loadtxt('1.58.d')
seq_7 = np.loadtxt('1.76.d')
seq_8 = np.loadtxt('3.01.d')
seq_9 = np.loadtxt('3.2.d')
seq_10 = np.loadtxt('3.11.d')
seq_11 = np.loadtxt('2.84.d')
seq_12 = np.loadtxt('2.77.d')
seq_13 = np.loadtxt('2.81.d')
seq_14 = np.loadtxt('../seq.d')

#Quasi
q_j = quasi[:,3]
q_f = quasi[:,5]
q_tw = quasi[:,8]
q_mg = quasi[:,4]
q_rho = quasi[:,12]
q_mb = quasi[:,9]


#Trial 
j_t = seq_t[:,3]
f_t = seq_t[:,5]
tw_t = seq_t[:,8]
mg_t = seq_t[:,4]
rho_t = seq_t[:,12]
mb_t = seq_t[:,9]



#Kepler
j_kep = seq_k[:,3]
f_kep = seq_k[:,5]
tw_kep = seq_k[:,8]
mg_kep = seq_k[:,4]
rho_kep = seq_k[:,12]
mb_kep = seq_k[:,9]


#Static
j_sta = seq_s[:,3]
f_sta = seq_s[:,5]
tw_sta = seq_s[:,8]
mg_sta = seq_s[:,4]
rho_sta = seq_s[:,12]
mb_sta = seq_s[:,9]

#Diffkep
j_dkep = seq_d[:,3]
f_dkep = seq_d[:,5]
tw_dkep = seq_d[:,8]
mg_dkep = seq_d[:,4]
rho_dkep = seq_d[:,12]
mb_dkep = seq_d[:,9]

#Mb=1.43
j_1 = seq_1[:,3]
f_1 = seq_1[:,5]
tw_1 = seq_1[:,8]
mg_1 = seq_1[:,4]
rho_1 = seq_1[:,12]
mb_1 = seq_1[:,9]

#Mb=2.01
j_2 = seq_2[:,3]
f_2 = seq_2[:,5]
tw_2 = seq_2[:,8]
mg_2 = seq_2[:,4]
rho_2 = seq_2[:,12]
mb_2 = seq_2[:,9]

#Mb=2.3
j_3 = seq_3[:,3]
f_3 = seq_3[:,5]
tw_3 = seq_3[:,8]
mg_3 = seq_3[:,4]
rho_3 = seq_3[:,12]
mb_3 = seq_3[:,9]

#Mb=2.64
j_4 = seq_4[:,3]
f_4 = seq_4[:,5]
tw_4 = seq_4[:,8]
mg_4 = seq_4[:,4]
rho_4 = seq_4[:,12]
mb_4 = seq_4[:,9]

#Mb=2.89
j_5 = seq_5[:,3]
f_5 = seq_5[:,5]
tw_5 = seq_5[:,8]
mg_5 = seq_5[:,4]
rho_5 = seq_5[:,12]
mb_5 = seq_5[:,9]

#Mb=1.58
j_6 = seq_6[:,3]
f_6 = seq_6[:,5]
tw_6 = seq_6[:,8]
mg_6 = seq_6[:,4]
rho_6 = seq_6[:,12]
mb_6 = seq_6[:,9]

#Mb=1.76
j_7 = seq_7[:,3]
f_7 = seq_7[:,5]
tw_7 = seq_7[:,8]
mg_7 = seq_7[:,4]
rho_7 = seq_7[:,12]
mb_7 = seq_7[:,9]


#Mb=3.01
j_8 = seq_8[:,3]
f_8 = seq_8[:,5]
tw_8 = seq_8[:,8]
mg_8 = seq_8[:,4]
rho_8 = seq_8[:,12]
mb_8 = seq_8[:,9]

#Mb=3.2
j_9 = seq_9[:,3]
f_9 = seq_9[:,5]
tw_9 = seq_9[:,8]
mg_9 = seq_9[:,4]
rho_9 = seq_9[:,12]
mb_9 = seq_9[:,9]


#Mb=3.09
j_10 = seq_10[:,3]
f_10 = seq_10[:,5]
tw_10 = seq_10[:,8]
mg_10 = seq_10[:,4]
rho_10 = seq_10[:,12]
mb_10 = seq_10[:,9]


#Mb=2.84
j_11 = seq_11[:,3]
f_11 = seq_11[:,5]
tw_11 = seq_11[:,8]
mg_11 = seq_11[:,4]
rho_11 = seq_11[:,12]
mb_11 = seq_11[:,9]

#Mb=2.77
j_12 = seq_12[:,3]
f_12 = seq_12[:,5]
tw_12 = seq_12[:,8]
mg_12 = seq_12[:,4]
rho_12 = seq_12[:,12]
mb_12 = seq_12[:,9]

#Mb=2.81
j_13 = seq_13[:,3]
f_13 = seq_13[:,5]
tw_13 = seq_13[:,8]
mg_13 = seq_13[:,4]
rho_13 = seq_13[:,12]
mb_13 = seq_13[:,9]

#Mb=2.795
j_14 = seq_14[:,3]
f_14 = seq_14[:,5]
tw_14 = seq_14[:,8]
mg_14 = seq_14[:,4]
rho_14 = seq_14[:,12]
mb_14 = seq_14[:,9]

# %%
plt.figure(figsize=(12,8))
plt.plot(rho_dkep,mg_dkep,label='Differential Kepler')
plt.plot(rho_kep,mg_kep,label='Uniform Kepler')
plt.plot(rho_sta,mg_sta,label='Static')
plt.plot(rho_2,mg_2,'--',color='limegreen',label='$M_b$ = 2.01')
plt.plot(rho_3,mg_3,'--',color='lightseagreen',label='$M_b$ = 2.30')
plt.plot(rho_4,mg_4,'--',color='brown',label='$M_b$ = 2.64')
#plt.plot(rho_11,mg_11,'--',label='$M_b$ = 2.70')
#plt.plot(rho_12,mg_12,'--',label='$M_b = 2.77$')
plt.plot(rho_5,mg_5,'--',color='magenta',label='$M_b$ = 2.89')
plt.plot(rho_8,mg_8,'--',color='purple',label='$M_b$ = 3.01')
plt.plot(rho_10,mg_10,'--',color='green',label='$M_b$ = 3.11')
plt.plot(rho_9,mg_9,'--',color='red',label='$M_b$ = 3.2')
plt.plot(10.241469,2.8734561,'*',color='black')
plt.plot(8.7665091,2.7745566,'*',color='black')
#plt.plot(q_rho,q_mg,'--',label='Quasi-Static Line')
plt.title('Differentially rotating stars at a=0.2 DD2 s2')
plt.xlabel(r'$\rho_{c}(\rho_{nuc}c^2)$')
plt.ylabel('$M_g(M_o)$')
plt.legend()
plt.grid('on')
plt.savefig('combined.png')

# %%
plt.figure(figsize=(12,8))
plt.plot(j_dkep,f_dkep,label='Diff Kepler')
plt.plot(j_kep,f_kep,label='Uni Kepler')
#plt.plot(j_t,f_t,label='Trial a=0.1')
plt.plot(j_2,f_2,'--',color='limegreen',label='$M_b$ = 2.01')
plt.plot(j_3,f_3,'--',color='lightseagreen',label='$M_b$ = 2.30')
plt.plot(j_4,f_4,'--',color='brown',label='$M_b$ = 2.64')
#plt.plot(j_11,f_11,'--',label='$M_b$ = 2.70')
#plt.plot(j_12,f_12,'--',label='$M_b = 2.77$')
plt.plot(j_5,f_5,'--',color='magenta',label='$M_b$ = 2.89')
plt.plot(j_8,f_8,'--',color='purple',label='$M_b$ = 3.01')
plt.plot(j_10,f_10,'--',color='red',label='$M_b$ = 3.11')
plt.plot(j_9,f_9,'--',color='green',label='$M_b$ = 3.20')
plt.plot(q_j,q_f,'--',color='slategray',label='Quasi-Static Line')
plt.title('Differentially rotating stars at a=0.2 DD2 s2')
plt.xlabel('Angular Momentum J $(GM^2_{sol}/c)$')
plt.ylabel('Frequency(Hz)')
plt.legend()
plt.grid('on')
plt.savefig('combined_j.png')

# %%
plt.figure(figsize=(12,8))
plt.plot(tw_dkep,f_dkep,label='Diff Kepler')
plt.plot(tw_kep,f_kep,label='Uni Kepler')
plt.plot(tw_2,f_2,'--',color='limegreen',label='$M_b$ = 2.01')
plt.plot(tw_3,f_3,'--',color='lightseagreen',label='$M_b$ = 2.30')
plt.plot(tw_4,f_4,'--',color='brown',label='$M_b$ = 2.64')
#plt.plot(tw_11,f_11,'--',label='$M_b$ = 2.70')
#plt.plot(tw_12,f_12,'--',label='$M_b = 2.77$')
#plt.plot(tw_13,f_13,'--',label='M_b =2.81')
#plt.plot(tw_14,f_14,'--',label='$M_b = 2.795$')
plt.plot(tw_5,f_5,'--',color='magenta',label='$M_b$ = 2.89')
plt.plot(tw_8,f_8,'--',color='purple',label='$M_b$ = 3.01')
plt.plot(tw_10,f_10,'--',color='red',label='$M_b$ = 3.11')
plt.plot(tw_9,f_9,'--',color='green',label='$M_b$ = 3.2')
plt.plot(q_tw,q_f,'--',color='slategray',label='Quasi-Static Line')
plt.title('Differentially rotating stars at a=0.2 DD2 s2')
plt.xlabel('$T/W$')
plt.ylabel('Frequency(Hz)')
plt.legend()
plt.grid('on')
plt.savefig('combined_tw.png')
