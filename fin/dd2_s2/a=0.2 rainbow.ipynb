# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Loading the files
dd2_s2_seq_kepp = np.loadtxt('kep.d')
dd2_s2_seq_stat = np.loadtxt('static.d')
dd2_s2_seq_diff = np.loadtxt('erm.d')
dd2_s2_seq_quas = np.loadtxt('quasi.d')
dd2_s2_seq_1 = np.loadtxt('1.43.d')
dd2_s2_seq_2 = np.loadtxt('2.01.d')
dd2_s2_seq_3 = np.loadtxt('2.3.d')
dd2_s2_seq_4 = np.loadtxt('2.64.d')
dd2_s2_seq_5 = np.loadtxt('2.89.d')
dd2_s2_seq_6 = np.loadtxt('1.58.d')
dd2_s2_seq_7 = np.loadtxt('1.76.d')
dd2_s2_seq_8 = np.loadtxt('3.01.d')
dd2_s2_seq_9 = np.loadtxt('3.2.d')
dd2_s2_seq_10 = np.loadtxt('3.11.d')
dd2_s2_seq_11 = np.loadtxt('2.84.d')
dd2_s2_seq_12 = np.loadtxt('2.77.d')
dd2_s2_seq_13 = np.loadtxt('2.81.d')

#Quasi
dd2_s2_j_qua = dd2_s2_seq_quas[:,3]
dd2_s2_f_qua = dd2_s2_seq_quas[:,5]
dd2_s2_tw_qua = dd2_s2_seq_quas[:,8]
dd2_s2_mg_qua = dd2_s2_seq_quas[:,4]
dd2_s2_rho_qua = dd2_s2_seq_quas[:,12]
dd2_s2_mb_qua = dd2_s2_seq_quas[:,9]

#Kepler
dd2_s2_j_kep = dd2_s2_seq_kepp[:,3]
dd2_s2_f_kep = dd2_s2_seq_kepp[:,5]
dd2_s2_tw_kep = dd2_s2_seq_kepp[:,8]
dd2_s2_mg_kep = dd2_s2_seq_kepp[:,4]
dd2_s2_rho_kep = dd2_s2_seq_kepp[:,12]
dd2_s2_mb_kep = dd2_s2_seq_kepp[:,9]

#Static
dd2_s2_j_sta = dd2_s2_seq_stat[:,3]
dd2_s2_f_sta = dd2_s2_seq_stat[:,5]
dd2_s2_tw_sta = dd2_s2_seq_stat[:,8]
dd2_s2_mg_sta = dd2_s2_seq_stat[:,4]
dd2_s2_rho_sta = dd2_s2_seq_stat[:,12]
dd2_s2_mb_sta = dd2_s2_seq_stat[:,9]

#Diffkep
dd2_s2_j_dkep = dd2_s2_seq_diff[:,3]
dd2_s2_f_dkep = dd2_s2_seq_diff[:,5]
dd2_s2_tw_dkep = dd2_s2_seq_diff[:,8]
dd2_s2_mg_dkep = dd2_s2_seq_diff[:,4]
dd2_s2_rho_dkep = dd2_s2_seq_diff[:,12]
dd2_s2_mb_dkep = dd2_s2_seq_diff[:,9]

#Mb=1.43
dd2_s2_j_1 = dd2_s2_seq_1[:,3]
dd2_s2_f_1 = dd2_s2_seq_1[:,5]
dd2_s2_tw_1 = dd2_s2_seq_1[:,8]
dd2_s2_mg_1 = dd2_s2_seq_1[:,4]
dd2_s2_rho_1 = dd2_s2_seq_1[:,12]
dd2_s2_mb_1 = dd2_s2_seq_1[:,9]

#Mb=2.01
dd2_s2_j_2 = dd2_s2_seq_2[:,3]
dd2_s2_f_2 = dd2_s2_seq_2[:,5]
dd2_s2_tw_2 = dd2_s2_seq_2[:,8]
dd2_s2_mg_2 = dd2_s2_seq_2[:,4]
dd2_s2_rho_2 = dd2_s2_seq_2[:,12]
dd2_s2_mb_2 = dd2_s2_seq_2[:,9]

#Mb=2.3
dd2_s2_j_3 = dd2_s2_seq_3[:,3]
dd2_s2_f_3 = dd2_s2_seq_3[:,5]
dd2_s2_tw_3 = dd2_s2_seq_3[:,8]
dd2_s2_mg_3 = dd2_s2_seq_3[:,4]
dd2_s2_rho_3 = dd2_s2_seq_3[:,12]
dd2_s2_mb_3 = dd2_s2_seq_3[:,9]

#Mb=2.64
dd2_s2_j_4 = dd2_s2_seq_4[:,3]
dd2_s2_f_4 = dd2_s2_seq_4[:,5]
dd2_s2_tw_4 = dd2_s2_seq_4[:,8]
dd2_s2_mg_4 = dd2_s2_seq_4[:,4]
dd2_s2_rho_4 = dd2_s2_seq_4[:,12]
dd2_s2_mb_4 = dd2_s2_seq_4[:,9]

#Mb=2.89
dd2_s2_j_5 = dd2_s2_seq_5[:,3]
dd2_s2_f_5 = dd2_s2_seq_5[:,5]
dd2_s2_tw_5 = dd2_s2_seq_5[:,8]
dd2_s2_mg_5 = dd2_s2_seq_5[:,4]
dd2_s2_rho_5 = dd2_s2_seq_5[:,12]
dd2_s2_mb_5 = dd2_s2_seq_5[:,9]

#Mb=1.58
dd2_s2_j_6 = dd2_s2_seq_6[:,3]
dd2_s2_f_6 = dd2_s2_seq_6[:,5]
dd2_s2_tw_6 = dd2_s2_seq_6[:,8]
dd2_s2_mg_6 = dd2_s2_seq_6[:,4]
dd2_s2_rho_6 = dd2_s2_seq_6[:,12]
dd2_s2_mb_6 = dd2_s2_seq_6[:,9]

#Mb=1.76
dd2_s2_j_7 = dd2_s2_seq_7[:,3]
dd2_s2_f_7 = dd2_s2_seq_7[:,5]
dd2_s2_tw_7 = dd2_s2_seq_7[:,8]
dd2_s2_mg_7 = dd2_s2_seq_7[:,4]
dd2_s2_rho_7 = dd2_s2_seq_7[:,12]
dd2_s2_mb_7 = dd2_s2_seq_7[:,9]


#Mb=3.01
dd2_s2_j_8 = dd2_s2_seq_8[:,3]
dd2_s2_f_8 = dd2_s2_seq_8[:,5]
dd2_s2_tw_8 = dd2_s2_seq_8[:,8]
dd2_s2_mg_8 = dd2_s2_seq_8[:,4]
dd2_s2_rho_8 = dd2_s2_seq_8[:,12]
dd2_s2_mb_8 = dd2_s2_seq_8[:,9]

#Mb=3.2
dd2_s2_j_9 = dd2_s2_seq_9[:,3]
dd2_s2_f_9 = dd2_s2_seq_9[:,5]
dd2_s2_tw_9 = dd2_s2_seq_9[:,8]
dd2_s2_mg_9 = dd2_s2_seq_9[:,4]
dd2_s2_rho_9 = dd2_s2_seq_9[:,12]
dd2_s2_mb_9 = dd2_s2_seq_9[:,9]


#Mb=3.09
dd2_s2_j_10 = dd2_s2_seq_10[:,3]
dd2_s2_f_10 = dd2_s2_seq_10[:,5]
dd2_s2_tw_10 = dd2_s2_seq_10[:,8]
dd2_s2_mg_10 = dd2_s2_seq_10[:,4]
dd2_s2_rho_10 = dd2_s2_seq_10[:,12]
dd2_s2_mb_10 = dd2_s2_seq_10[:,9]


#Mb=2.84
dd2_s2_j_11 = dd2_s2_seq_11[:,3]
dd2_s2_f_11 = dd2_s2_seq_11[:,5]
dd2_s2_tw_11 = dd2_s2_seq_11[:,8]
dd2_s2_mg_11 = dd2_s2_seq_11[:,4]
dd2_s2_rho_11 = dd2_s2_seq_11[:,12]
dd2_s2_mb_11 = dd2_s2_seq_11[:,9]

#Mb=2.77
dd2_s2_j_12 = dd2_s2_seq_12[:,3]
dd2_s2_f_12 = dd2_s2_seq_12[:,5]
dd2_s2_tw_12 = dd2_s2_seq_12[:,8]
dd2_s2_mg_12 = dd2_s2_seq_12[:,4]
dd2_s2_rho_12 = dd2_s2_seq_12[:,12]
dd2_s2_mb_12 = dd2_s2_seq_12[:,9]

#Mb=2.81
dd2_s2_j_13 = dd2_s2_seq_13[:,3]
dd2_s2_f_13 = dd2_s2_seq_13[:,5]
dd2_s2_tw_13 = dd2_s2_seq_13[:,8]
dd2_s2_mg_13 = dd2_s2_seq_13[:,4]
dd2_s2_rho_13 = dd2_s2_seq_13[:,12]
dd2_s2_mb_13 = dd2_s2_seq_13[:,9]

# %%
plt.figure(figsize=(12,8))
plt.ylim(0.5,3.2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.plot(rho_dkep,mg_dkep,label='Differential Kepler')
plt.plot(rho_kep,mg_kep,label='Uniform Kepler')
plt.plot(rho_sta,mg_sta,label='Static',color='black')
plt.plot(rho_2,mg_2,'--',color='limegreen',label='$M_b$ = 2.01')
plt.plot(rho_3,mg_3,'--',color='lightseagreen',label='$M_b$ = 2.30')
plt.plot(rho_4,mg_4,'--',color='brown',label='$M_b$ = 2.64')
#plt.plot(rho_11,mg_11,'--',label='$M_b$ = 2.70')
#plt.plot(rho_12,mg_12,'--',label='$M_b = 2.77$')
plt.plot(rho_5,mg_5,'--',color='magenta',label='$M_b$ = 2.89')
plt.plot(rho_8,mg_8,'--',color='purple',label='$M_b$ = 3.01')
plt.plot(rho_10,mg_10,'--',color='green',label='$M_b$ = 3.11')
plt.plot(rho_9,mg_9,'--',color='red',label='$M_b$ = 3.2')
#plt.plot(10.241469,2.8734561,'*',color='black')
#plt.plot(9.9979098,2.7856637,'*',color='black')
#plt.plot(q_rho,q_mg,'--',label='Quasi-Static Line')
plt.title('DD2 s2',fontsize=20)
plt.xlabel(r'$\rho_{c}(\rho_{nuc}c^2)$',fontsize=20)
plt.ylabel('$M_g(M_o)$',fontsize=20)
plt.legend(prop={"size":15})
plt.grid('on')
plt.savefig('combined.png')

# %%
plt.figure(figsize=(12,8))
plt.plot(j_dkep,f_dkep,label='Diff Kepler')
plt.plot(j_kep,f_kep,label='Uni Kepler')
#plt.plot(j_t,f_t,label='Trial a=0.1')
plt.plot(j_2,f_2,'--',color='limegreen',label='$M_b$ = 2.01')
plt.plot(j_3,f_3,'--',color='lightseagreen',label='$M_b$ = 2.30')
plt.plot(j_4,f_4,'--',color='brown',label='$M_b$ = 2.64')
#plt.plot(j_11,f_11,'--',label='$M_b$ = 2.70')
#plt.plot(j_12,f_12,'--',label='$M_b = 2.77$')
plt.plot(j_5,f_5,'--',color='magenta',label='$M_b$ = 2.89')
plt.plot(j_8,f_8,'--',color='purple',label='$M_b$ = 3.01')
plt.plot(j_10,f_10,'--',color='red',label='$M_b$ = 3.11')
plt.plot(j_9,f_9,'--',color='green',label='$M_b$ = 3.20')
plt.plot(q_j,q_f,'--',color='slategray',label='Quasi-Static Line')
plt.title('Differentially rotating stars at a=0.2 DD2 s2')
plt.xlabel('Angular Momentum J $(GM^2_{sol}/c)$')
plt.ylabel('Frequency(Hz)')
plt.legend()
plt.grid('on')
plt.savefig('combined_j.png')

# %%
plt.figure(figsize=(12,8))
plt.plot(tw_dkep,f_dkep,label='Diff Kepler')
plt.plot(tw_kep,f_kep,label='Uni Kepler')
plt.plot(tw_2,f_2,'--',color='limegreen',label='$M_b$ = 2.01')
plt.plot(tw_3,f_3,'--',color='lightseagreen',label='$M_b$ = 2.30')
plt.plot(tw_4,f_4,'--',color='brown',label='$M_b$ = 2.64')
#plt.plot(tw_11,f_11,'--',label='$M_b$ = 2.70')
#plt.plot(tw_12,f_12,'--',label='$M_b = 2.77$')
#plt.plot(tw_13,f_13,'--',label='M_b =2.81')
#plt.plot(tw_14,f_14,'--',label='$M_b = 2.795$')
plt.plot(tw_5,f_5,'--',color='magenta',label='$M_b$ = 2.89')
plt.plot(tw_8,f_8,'--',color='purple',label='$M_b$ = 3.01')
plt.plot(tw_10,f_10,'--',color='red',label='$M_b$ = 3.11')
plt.plot(tw_9,f_9,'--',color='green',label='$M_b$ = 3.2')
plt.plot(q_tw,q_f,'--',color='slategray',label='Quasi-Static Line')
plt.title('Differentially rotating stars at a=0.2 DD2 s2')
plt.xlabel('$T/W$')
plt.ylabel('Frequency(Hz)')
plt.legend()
plt.grid('on')
plt.savefig('combined_tw.png')
