# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.interpolate as interpolate

# %%
#Loading the files
seq_diff = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s0/ermehgerd.d')
seq_stat = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s0/static.d')
seq_kepp = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s0/kepp.d')
seq_1 = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s0/3.30diff.d')
seq_2 = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s0/2.01diff.d')
seq_3 = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s0/2.30diff.d')
seq_4 = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s0/2.64diff.d')
seq_5 = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s0/2.89diff.d')
seq_6 = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s0/3.01diff.d')
seq_7 = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s0/3.20diff.d')
seq_8 = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s0/3.51diff.d')
bhb_diff = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s2/bhb_ermehgerd.d')
bhb_stat = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s2/bhb_static.d')
bhb_kepp = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s2/bhb_kepp.d')
bhb_1 = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s2/bhb_2.01diff.d')
bhb_2 = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_S2/bhb_2.30diff.d')
bhb_3 = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s2/bhb_2.64diff.d')
bhb_4 = np.loadtxt('/home/chatrik/soft/Lorene/Codes/Rot_star/dd2_s2/bhb_2.89diff.d')


#Differential Kepler
j_dif = seq_diff[:,3]
f_dif = seq_diff[:,5]
tw_dif = seq_diff[:,8]
mg_dif = seq_diff[:,4]
rho_dif = seq_diff[:,12]
mb_dif = seq_diff[:,9]

#Uniform Kepler
j_kep = seq_kepp[:,3]
f_kep = seq_kepp[:,5]
tw_kep = seq_kepp[:,8]
mg_kep = seq_kepp[:,4]
rho_kep = seq_kepp[:,12]
mb_kep = seq_kepp[:,9]

#Static
j_sta = seq_stat[:,3]
f_sta = seq_stat[:,5]
tw_sta = seq_stat[:,8]
mg_sta = seq_stat[:,4]
rho_sta = seq_stat[:,12]
mb_sta = seq_stat[:,9]

#BHB Differential Kepler
j_bdif = bhb_diff[:,3]
f_bdif = bhb_diff[:,5]
tw_bdif = bhb_diff[:,8]
mg_bdif = bhb_diff[:,4]
rho_bdif = bhb_diff[:,12]
mb_bdif = bhb_diff[:,9]

#BHB Uniform Kepler
j_bkep = bhb_kepp[:,3]
f_bkep = bhb_kepp[:,5]
tw_bkep = bhb_kepp[:,8]
mg_bkep = bhb_kepp[:,4]
rho_bkep = bhb_kepp[:,12]
mb_bkep = bhb_kepp[:,9]

#BHB Static
j_bsta = bhb_stat[:,3]
f_bsta = bhb_stat[:,5]
tw_bsta = bhb_stat[:,8]
mg_bsta = bhb_stat[:,4]
rho_bsta = bhb_stat[:,12]
mb_bsta = bhb_stat[:,9]


#Mb=1.287
j_1 = seq_1[:,3]
f_1 = seq_1[:,5]
tw_1 = seq_1[:,8]
mg_1 = seq_1[:,4]
rho_1 = seq_1[:,12]
mb_1 = seq_1[:,9]

#Mb=1.712
j_2 = seq_2[:,3]
f_2 = seq_2[:,5]
tw_2 = seq_2[:,8]
mg_2 = seq_2[:,4]
rho_2 = seq_2[:,12]
mb_2 = seq_2[:,9]

#Mb=2.177
j_3 = seq_3[:,3]
f_3 = seq_3[:,5]
tw_3 = seq_3[:,8]
mg_3 = seq_3[:,4]
rho_3 = seq_3[:,12]
mb_3 = seq_3[:,9]

#Mb=2.415
j_4 = seq_4[:,3]
f_4 = seq_4[:,5]
tw_4 = seq_4[:,8]
mg_4 = seq_4[:,4]
rho_4 = seq_4[:,12]
mb_4 = seq_4[:,9]

#Mb=2.692
j_5 = seq_5[:,3]
f_5 = seq_5[:,5]
tw_5 = seq_5[:,8]
mg_5 = seq_5[:,4]
rho_5 = seq_5[:,12]
mb_5 = seq_5[:,9]

#Mb=2.866
j_6 = seq_6[:,3]
f_6 = seq_6[:,5]
tw_6 = seq_6[:,8]
mg_6 = seq_6[:,4]
rho_6 = seq_6[:,12]
mb_6 = seq_6[:,9]

#Mb=2.966
j_7 = seq_7[:,3]
f_7 = seq_7[:,5]
tw_7 = seq_7[:,8]
mg_7 = seq_7[:,4]
rho_7 = seq_7[:,12]
mb_7 = seq_7[:,9]

#Mb=2.966
j_8 = seq_8[:,3]
f_8 = seq_8[:,5]
tw_8 = seq_8[:,8]
mg_8 = seq_8[:,4]
rho_8 = seq_8[:,12]
mb_8 = seq_8[:,9]

#Mb=1.287
j_b1 = bhb_1[:,3]
f_b1 = bhb_1[:,5]
tw_b1 = bhb_1[:,8]
mg_b1 = bhb_1[:,4]
rho_b1 = bhb_1[:,12]
mb_b1 = bhb_1[:,9]

#Mb=1.712
j_b2 = bhb_2[:,3]
f_b2 = bhb_2[:,5]
tw_b2 = bhb_2[:,8]
mg_b2 = bhb_2[:,4]
rho_b2 = bhb_2[:,12]
mb_b2 = bhb_2[:,9]

#Mb=2.177
j_b3 = bhb_3[:,3]
f_b3 = bhb_3[:,5]
tw_b3 = bhb_3[:,8]
mg_b3 = bhb_3[:,4]
rho_b3 = bhb_3[:,12]
mb_b3 = bhb_3[:,9]

#Mb=2.415
j_b4 = bhb_4[:,3]
f_b4 = bhb_4[:,5]
tw_b4 = bhb_4[:,8]
mg_b4 = bhb_4[:,4]
rho_b4 = bhb_4[:,12]
mb_b4 = bhb_4[:,9]

# %%
plt.figure(figsize=(12,8))
plt.plot(rho_dif,mg_dif,label='Differential Kepler', color='blue')
plt.plot(rho_kep,mg_kep,label='Uniform Kepler',color='orange')
plt.plot(rho_sta,mg_sta,label='Static', color='black')
#plt.plot(rho_1,mg_1,label='$M_b$ = 3.30')
plt.plot(rho_2,mg_2,label='$M_b$ = 2.01', color='green')
plt.plot(rho_3,mg_3,label='$M_b$ = 2.30', color='red')
plt.plot(rho_4,mg_4,label='$M_b$ = 2.64', color='yellow')
plt.plot(rho_5,mg_5,label='$M_b$ = 2.89', color='purple')
#plt.plot(rho_6,mg_6,label='$M_b$ = 3.01')
#plt.plot(rho_7,mg_7,label='$M_b$ = 3.20')
#plt.plot(rho_8,mg_8,label='$M_b$ = 3.51')
plt.plot(rho_bdif,mg_bdif,label='Differential Kepler', color='blue', linestyle='--')
plt.plot(rho_bkep,mg_bkep,label='Uniform Kepler', color='orange', linestyle='--')
plt.plot(rho_bsta,mg_bsta,label='Static', color='black', linestyle='--')
plt.plot(rho_b1,mg_b1,label='$M_b$ = 2.01', color='green', linestyle='--')
plt.plot(rho_b2,mg_b2,label='$M_b$ = 2.30', color='red', linestyle='--')
plt.plot(rho_b3,mg_b3,label='$M_b$ = 2.64', color='yellow', linestyle='--')
plt.plot(rho_b4,mg_b4,label='$M_b$ = 2.89', color='purple', linestyle='--')
plt.title('Differentially rotating stars at a=0.2')
plt.xlabel("rho_c ($rho_{nuc}c^2)$",size=15)
plt.ylabel("$M_g$ ($M_0$)",size=15)
plt.legend()
plt.grid('on')
plt.savefig('dd2_bhb_mass.png')

# %%
plt.figure(figsize=(12,8))
plt.plot(j_dif,f_dif,label='Differential Kepler', color='blue')
plt.plot(j_kep,f_kep,label='Uniform Kepler',color='orange')
#plt.plot(j_sta,f_sta,label='Static', color='black')
#plt.plot(j_1,f_1,label='$M_b$ = 3.30')
plt.plot(j_2,f_2,label='$M_b$ = 2.01', color='green')
plt.plot(j_3,f_3,label='$M_b$ = 2.30', color='red')
plt.plot(j_4,f_4,label='$M_b$ = 2.64', color='yellow')
plt.plot(j_5,f_5,label='$M_b$ = 2.89', color='purple')
#plt.plot(j_6,f_6,label='$M_b$ = 3.01')
#plt.plot(j_7,f_7,label='$M_b$ = 3.20')
#plt.plot(j_8,f_8,label='$M_b$ = 3.51')
plt.plot(j_bdif,f_bdif,label='Differential Kepler', color='blue', linestyle='--')
plt.plot(j_bkep,f_bkep,label='Uniform Kepler', color='orange', linestyle='--')
#plt.plot(j_bsta,f_bsta,label='Static', color='black', linestyle='--')
plt.plot(j_b1,f_b1,label='$M_b$ = 2.01', color='green', linestyle='--')
plt.plot(j_b2,f_b2,label='$M_b$ = 2.30', color='red', linestyle='--')
plt.plot(j_b3,f_b3,label='$M_b$ = 2.64', color='yellow', linestyle='--')
plt.plot(j_b4,f_b4,label='$M_b$ = 2.89', color='purple', linestyle='--')
plt.title('Differentially rotating stars at a=0.2')
plt.xlabel("Angular Momentum J ($G M_{sol}^2/c$)",size=15)
plt.ylabel("Frequency (Hz)",size=15)
plt.legend()
plt.grid('on')
plt.savefig('dd2_bhb_j.png')

# %%
plt.figure(figsize=(12,8))
plt.plot(tw_dif,f_dif,label='Differential Kepler', color='blue')
plt.plot(tw_kep,f_kep,label='Uniform Kepler',color='orange')
#plt.plot(tw_sta,f_sta,label='Static', color='black')
#plt.plot(tw_1,f_1,label='$M_b$ = 3.30')
plt.plot(tw_2,f_2,label='$M_b$ = 2.01', color='green')
plt.plot(tw_3,f_3,label='$M_b$ = 2.30', color='red')
plt.plot(tw_4,f_4,label='$M_b$ = 2.64', color='yellow')
plt.plot(tw_5,f_5,label='$M_b$ = 2.89', color='purple')
#plt.plot(tw_6,f_6,label='$M_b$ = 3.01')
#plt.plot(tw_7,f_7,label='$M_b$ = 3.20')
#plt.plot(tw_8,f_8,label='$M_b$ = 3.51')
plt.plot(tw_bdif,f_bdif,label='Differential Kepler', color='blue', linestyle='--')
plt.plot(tw_bkep,f_bkep,label='Uniform Kepler', color='orange', linestyle='--')
#plt.plot(tw_bsta,f_bsta,label='Static', color='black', linestyle='--')
plt.plot(tw_b1,f_b1,label='$M_b$ = 2.01', color='green', linestyle='--')
plt.plot(tw_b2,f_b2,label='$M_b$ = 2.30', color='red', linestyle='--')
plt.plot(tw_b3,f_b3,label='$M_b$ = 2.64', color='yellow', linestyle='--')
plt.plot(tw_b4,f_b4,label='$M_b$ = 2.89', color='purple', linestyle='--')
plt.title('Differentially rotating stars at a=0.2')
plt.xlabel("T/W",size=15)
plt.ylabel("Frequency (Hz)",size=15)
plt.legend()
plt.grid('on')
plt.savefig('dd2_bhb_tw.png')

# %%
plt.figure(figsize=(12,8))
plt.plot(j_dif/mb_dif**2,f_dif,label='Differential Kepler', color='blue')
plt.plot(j_kep/mb_kep**2,f_kep,label='Uniform Kepler',color='orange')
#plt.plot(j_sta/mb_sta**2,f_sta,label='Static', color='black')
#plt.plot(j_1/mb_1**2,f_1,label='$M_b$ = 3.30')
plt.plot(j_2/mb_2**2,f_2,label='$M_b$ = 2.01', color='green')
plt.plot(j_3/mb_3**2,f_3,label='$M_b$ = 2.30', color='red')
plt.plot(j_4/mb_4**2,f_4,label='$M_b$ = 2.64', color='yellow')
plt.plot(j_5/mb_5**2,f_5,label='$M_b$ = 2.89', color='purple')
#plt.plot(j_6/mb_6**2,f_6,label='$M_b$ = 3.01')
#plt.plot(j_7/mb_7**2,f_7,label='$M_b$ = 3.20')
#plt.plot(j_8/mb_8**2,f_8,label='$M_b$ = 3.51')
plt.plot(j_bdif/mb_bdif**2,f_bdif,label='Differential Kepler', color='blue', linestyle='--')
plt.plot(j_bkep/mb_bkep**2,f_bkep,label='Uniform Kepler', color='orange', linestyle='--')
#plt.plot(j_bsta/mb_bsta**2,f_bsta,label='Static', color='black', linestyle='--')
plt.plot(j_b1/mb_b1**2,f_b1,label='$M_b$ = 2.01', color='green', linestyle='--')
plt.plot(j_b2/mb_b2**2,f_b2,label='$M_b$ = 2.30', color='red', linestyle='--')
plt.plot(j_b3/mb_b3**2,f_b3,label='$M_b$ = 2.64', color='yellow', linestyle='--')
plt.plot(j_b4/mb_b4**2,f_b4,label='$M_b$ = 2.89', color='purple', linestyle='--')
plt.title('Differentially rotating stars at a=0.2')
plt.xlabel("Angular Momentum J",size=15)
plt.ylabel("Frequency (Hz)",size=15)
plt.legend()
plt.grid('on')
plt.savefig('dd2_bhb_jmb2.png')
